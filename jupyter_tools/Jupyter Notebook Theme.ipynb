# %% [markdown]
# # Jupyter Notebook Theme

# %% [markdown]
# >[github地址](https://github.com/dunovank/jupyter-themes)

# %%
# !pip install  --no-dependencies jupyterthemes --user

# %%
# !pip install lesscpy --user

# %%
# !jt -h
# Out:
# /bin/sh: 1: jt: not found

# %%
# !jt -l
# Out:
# /bin/sh: 1: jt: not found

# %%
# !jt -t chesterish --lineh 140 -f hack -fs 12 -ofs 12 -nfs 12 -tfs 12  -T -N -cellw 90% -kl
# Out:
# /bin/sh: 1: jt: not found

# %% [markdown]
# ## jupyter notebook 实现自动代码补全，首先安装 nbextensions

# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# ...
#      |████████████████████████████████| 20.9MB 235kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 481kB 247kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 276kB 212kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 870kB 130kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.7MB 576kB/s eta 0:00:01
# ...
#   Stored in directory: /home/hapeak/.cache/pip/wheels/15/df/fe/2a74fe34709e7fdc5ae153a768675d9fda93cc7d5133ed1fb0
# ...
#   Stored in directory: /home/hapeak/.cache/pip/wheels/ad/56/bc/1522f864feb2a358ea6f1a92b4798d69ac783a28e80567a18b
# ...
#   Stored in directory: /home/hapeak/.cache/pip/wheels/0d/71/2a/164491997299b9f2479a251e254323fe35d946779e18f27956
# Successfully built jupyter-nbextensions-configurator pyyaml jupyter-latex-envs
# ...

# %%
# !jupyter contrib nbextension install --user
# Out:
# [I 19:03:30 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 19:03:30 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 19:03:30 InstallContribNbextensionsApp] Installing /home/hapeak/.conda/envs/datas/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 19:03:30 InstallContribNbextensionsApp] Making directory: /home/hapeak/.local/share/jupyter/nbextensions/select_keymap/
# [I 19:03:30 InstallContribNbextensionsApp] Copying: /home/hapeak/.conda/envs/datas/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/select_keymap.yaml -> /home/hapeak/.local/share/jupyter/nbextensions/select_keymap/select_keymap.yaml
# ...

# %% [markdown]
# ## 然后安装 nbextensions_configurator

# %%
# !pip install jupyter_nbextensions_configurator

# %%
# !jupyter nbextensions_configurator enable --user
# Out:
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /home/hapeak/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
